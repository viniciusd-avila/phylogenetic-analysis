# %% [markdown]
# Requere:
# * Baixar o arquivo [MNIST original](https://github.com/amplab/datascience-sp14/blob/master/lab7/mldata/mnist-original.mat) e salvar na pasta ~/scikit_learn_data/mldata/
# * instalar ggplot
# * alterar smoothers.py em ../python3.7/site-packages/ggplot/stats/, trocar import pandas.lib para import pandas

# %%
import numpy as np
from sklearn.datasets import fetch_mldata


mnist = fetch_mldata("MNIST original")
X = mnist.data / 255.0
y = mnist.target

print(X.shape, y.shape)

# %%
import pandas as pd


feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = y
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None


print('Size of the dataframe: {}'.format(df.shape))
# Out:
# Size of the dataframe: (70000, 785)

# %%
rndperm = np.random.permutation(df.shape[0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


# Plot the graph
plt.gray()
fig = plt.figure( figsize=(16,7) )
for i in range(0,30):
    ax = fig.add_subplot(3,10,i+1, title='Digit: ' + str(df.loc[rndperm[i],'label']) )
    ax.matshow(df.loc[rndperm[i],feat_cols].values.reshape((28,28)).astype(float))

plt.show()

# %%
import time

from sklearn.manifold import TSNE

n_sne = 7000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)


print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7000 samples in 0.288s...
# [t-SNE] Computed neighbors for 7000 samples in 58.746s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7000
# [t-SNE] Computed conditional probabilities for sample 2000 / 7000
# [t-SNE] Computed conditional probabilities for sample 3000 / 7000
# [t-SNE] Computed conditional probabilities for sample 4000 / 7000
# [t-SNE] Computed conditional probabilities for sample 5000 / 7000
# [t-SNE] Computed conditional probabilities for sample 6000 / 7000
# [t-SNE] Computed conditional probabilities for sample 7000 / 7000
# [t-SNE] Mean sigma: 2.239085
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.099915
# [t-SNE] KL divergence after 300 iterations: 2.419530
# t-SNE done! Time elapsed: 74.84555244445801 seconds

# %%
from ggplot import *

df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

chart = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=70,alpha=0.1) \
        + ggtitle("tSNE dimensions colored by digit")
chart
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
